# %% [markdown]
# #### 1. **Model Runner Step Sync And Async Testing**
#
# Notebook tests `ModelRunnerStep` within a serving graph to enable real-time monitoring and drift detection with MLRun.
# The main focus is to test te preformance of sync and async usage.

# %%
# Import mlrun and create project instance
import mlrun

image = "mlrun/mlrun"
project_name = "monitored-model-runner-naive"
project = mlrun.get_or_create_project(project_name, context="./",user_project=True, allow_cross_project=True)
# Out:
# > 2025-10-27 12:14:42,841 [info] Project loaded successfully: {"project_name":"monitored-model-runner-naive-matanz"}

# %%
# Import tools
import pandas as pd
from sklearn.svm import SVC
import pickle
from sklearn.datasets import load_iris
from mlrun.features import Feature

# %%
# Train simple SVM model on Iris dataset, save it and reformat the DS as list
iris = load_iris()
clf = SVC()           
clf.fit(iris.data, iris.target)
with open("SVM.pkl", "wb") as fh:
    pickle.dump(clf, fh)
iris_data = iris["data"].tolist()

# load the dataset again as a DF
iris = load_iris()
train_set = pd.DataFrame(
    iris["data"],
    columns=["sepal_length_cm", "sepal_width_cm", "petal_length_cm", "petal_width_cm"],
)

# Create a Model Artifact in the project using the trained model
model_name = "SVM"
model_artifact = project.log_model(
    model_name,
    model_file="SVM.pkl",
    training_set=train_set,
    framework="sklearn",
    outputs=[Feature(name="label")],
)

# %% [markdown]
# #### 5. Define your function and ModelRunnerStep
#
# Define functions to all the edge cases

# %%
# Config the code path and the serving function sync and async
sync_code_path = r"model_class_sync.py"
bouth_code_path = r"model_class_bouth.py"

async_sync_function = project.set_function(func=sync_code_path,image="mlrun/mlrun",kind="serving",name="async")
bouth_function = project.set_function(func=bouth_code_path,image="mlrun/mlrun",kind="serving",name="bouth")

# %%
from mlrun.serving.states import ModelRunnerStep

model_runner_step = ModelRunnerStep(
    name="my_runner", model_selector="MyModelSelector",model_selector_parameters={"name":"my-selector"})

for i in range(100):
    model_runner_step.add_model(
        model_class="MyModel",
        endpoint_name=f"my-{i}-model",
        model_artifact=model_artifact,
        input_path="inputs.here",
        result_path="outputs",
        outputs=["label"],
        execution_mechanism="asyncio",
    )

# %% [markdown]
# #### 6. Build graphs to all the edge cases
#
# description

# %%
async_graph_defined = bouth_function.set_topology("flow",engine="async")
async_graph_defined.to("MyPreprocessStep").to(model_runner_step).to("MyEnrichStep").respond()
async_graph_defined.plot()

async_graph_undefined = async_sync_function.set_topology("flow",engine="async")
async_graph_undefined.to("MyPreprocessStep").to(model_runner_step).to("MyEnrichStep").respond()
async_graph_undefined.plot()

# %% [markdown]
# #### Run using mock
#
# descteption

# %%
# 4. create mock server and test it locally (no k8s / deployment)

async_undefined_mock_server = bouth_function.to_mock_server()
async_defined_mock_server = async_sync_function.to_mock_server()
# Out:
# > 2025-10-27 12:15:51,377 [info] Server graph after adding system steps: {"graph":"{'MyPreprocessStep': {'class_name': 'MyPreprocessStep', 'kind': 'task'}, 'my_runner': {'model_endpoint_creation_strategy': 'skip', 'class_name': 'mlrun.serving.ModelRunner', 'endpoint_type': 1, 'shape': 'folder', 'after': ['MyPreprocessStep'], 'class_args': {'model_selector': ('MyModelSelector', {'name': 'my-selector'}), execution_mechanism_by_model_name: {'my-0-model': 'naive', 'my-1-model': 'naive', 'my-2-model': 'naive', 'my-3-model': 'naive', 'my-4-model': 'naive', 'my-5-model': 'naive', 'my-6-model': 'naive', 'my-7-model': 'naive', 'my-8-model': 'naive', 'my-9-model': 'naive', 'my-10-model': 'naive', 'my-11-model': 'naive', 'my-12-model': 'naive', 'my-13-model': 'naive', 'my-14-model': 'naive', 'my-15-model': 'naive', 'my-16-model': 'naive', 'my-17-model': 'naive', 'my-18-model': 'naive', 'my-19-model': 'naive', 'my-20-model': 'naive', 'my-21-model': 'naive', 'my-22-model': 'naive', 'my-23-model': 'naive', 'my-24-model': 'naive', 'my-25-model': 'naive', 'my-26-model': 'naive', 'my-27-model': 'naive', 'my-28-model': 'naive', 'my-29-model': 'naive', 'my-30-model': 'naive', 'my-31-model': 'naive', 'my-32-model': 'naive', 'my-33-model': 'naive', 'my-34-model': 'naive', 'my-35-model': 'naive', 'my-36-model': 'naive', 'my-37-model': 'naive', 'my-38-model': 'naive', 'my-39-model': 'naive', 'my-40-model': 'naive', 'my-41-model': 'naive', 'my-42-model': 'naive', 'my-43-model': 'naive', 'my-44-model': 'naive', 'my-45-model': 'naive', 'my-46-model': 'naive', 'my-47-model': 'naive', 'my-48-model': 'naive', 'my-49-model': 'naive', 'my-50-model': 'naive', 'my-51-model': 'naive', 'my-52-model': 'naive', 'my-53-model': 'naive', 'my-54-model': 'naive', 'my-55-model': 'naive', 'my-56-model': 'naive', 'my-57-model': 'naive', 'my-58-model': 'naive', 'my-59-model': 'naive', 'my-60-model': 'naive', 'my-61-model': 'naive', 'my-62-model': 'naive', 'my-63-model': 'naive', 'my-64-model': 'naive', 'my-65-model': 'naive', 'my-66-model': 'naive', 'my-67-model': 'naive', 'my-68-model': 'naive', 'my-69-model': 'naive', 'my-70-model': 'naive', 'my-71-model': 'naive', 'my-72-model': 'naive', 'my-73-model': 'naive', 'my-74-model': 'naive', 'my-75-model': 'naive', 'my-76-model': 'naive', 'my-77-model': 'naive', 'my-78-model': 'naive', 'my-79-model': 'naive', 'my-80-model': 'naive', 'my-81-model': 'naive', 'my-82-model': 'naive', 'my-83-model': 'naive', 'my-84-model': 'naive', 'my-85-model': 'naive', 'my-86-model': 'naive', 'my-87-model': 'naive', 'my-88-model': 'naive', 'my-89-model': 'naive', 'my-90-model': 'naive', 'my-91-model': 'naive', 'my-92-model': 'naive', 'my-93-model': 'naive', 'my-94-model': 'naive', 'my-95-model': 'naive', 'my-96-model': 'naive', 'my-97-model': 'naive', 'my-98-model': 'naive', 'my-99-model': 'naive'}, models: {'my-0-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-0-model'}), 'my-1-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-1-model'}), 'my-2-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-2-model'}), 'my-3-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-3-model'}), 'my-4-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-4-model'}), 'my-5-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc ...
# > 2025-10-27 12:15:53,666 [info] Server graph after adding system steps: {"graph":"{'MyPreprocessStep': {'class_name': 'MyPreprocessStep', 'kind': 'task'}, 'my_runner': {'model_endpoint_creation_strategy': 'skip', 'class_name': 'mlrun.serving.ModelRunner', 'endpoint_type': 1, 'shape': 'folder', 'after': ['MyPreprocessStep'], 'class_args': {'model_selector': ('MyModelSelector', {'name': 'my-selector'}), execution_mechanism_by_model_name: {'my-0-model': 'naive', 'my-1-model': 'naive', 'my-2-model': 'naive', 'my-3-model': 'naive', 'my-4-model': 'naive', 'my-5-model': 'naive', 'my-6-model': 'naive', 'my-7-model': 'naive', 'my-8-model': 'naive', 'my-9-model': 'naive', 'my-10-model': 'naive', 'my-11-model': 'naive', 'my-12-model': 'naive', 'my-13-model': 'naive', 'my-14-model': 'naive', 'my-15-model': 'naive', 'my-16-model': 'naive', 'my-17-model': 'naive', 'my-18-model': 'naive', 'my-19-model': 'naive', 'my-20-model': 'naive', 'my-21-model': 'naive', 'my-22-model': 'naive', 'my-23-model': 'naive', 'my-24-model': 'naive', 'my-25-model': 'naive', 'my-26-model': 'naive', 'my-27-model': 'naive', 'my-28-model': 'naive', 'my-29-model': 'naive', 'my-30-model': 'naive', 'my-31-model': 'naive', 'my-32-model': 'naive', 'my-33-model': 'naive', 'my-34-model': 'naive', 'my-35-model': 'naive', 'my-36-model': 'naive', 'my-37-model': 'naive', 'my-38-model': 'naive', 'my-39-model': 'naive', 'my-40-model': 'naive', 'my-41-model': 'naive', 'my-42-model': 'naive', 'my-43-model': 'naive', 'my-44-model': 'naive', 'my-45-model': 'naive', 'my-46-model': 'naive', 'my-47-model': 'naive', 'my-48-model': 'naive', 'my-49-model': 'naive', 'my-50-model': 'naive', 'my-51-model': 'naive', 'my-52-model': 'naive', 'my-53-model': 'naive', 'my-54-model': 'naive', 'my-55-model': 'naive', 'my-56-model': 'naive', 'my-57-model': 'naive', 'my-58-model': 'naive', 'my-59-model': 'naive', 'my-60-model': 'naive', 'my-61-model': 'naive', 'my-62-model': 'naive', 'my-63-model': 'naive', 'my-64-model': 'naive', 'my-65-model': 'naive', 'my-66-model': 'naive', 'my-67-model': 'naive', 'my-68-model': 'naive', 'my-69-model': 'naive', 'my-70-model': 'naive', 'my-71-model': 'naive', 'my-72-model': 'naive', 'my-73-model': 'naive', 'my-74-model': 'naive', 'my-75-model': 'naive', 'my-76-model': 'naive', 'my-77-model': 'naive', 'my-78-model': 'naive', 'my-79-model': 'naive', 'my-80-model': 'naive', 'my-81-model': 'naive', 'my-82-model': 'naive', 'my-83-model': 'naive', 'my-84-model': 'naive', 'my-85-model': 'naive', 'my-86-model': 'naive', 'my-87-model': 'naive', 'my-88-model': 'naive', 'my-89-model': 'naive', 'my-90-model': 'naive', 'my-91-model': 'naive', 'my-92-model': 'naive', 'my-93-model': 'naive', 'my-94-model': 'naive', 'my-95-model': 'naive', 'my-96-model': 'naive', 'my-97-model': 'naive', 'my-98-model': 'naive', 'my-99-model': 'naive'}, models: {'my-0-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-0-model'}), 'my-1-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-1-model'}), 'my-2-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-2-model'}), 'my-3-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-3-model'}), 'my-4-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc6ac4^12da2786e9b8e028827413774a8a2701f7f638b9', 'name': 'my-4-model'}), 'my-5-model': ('MyModel', {'artifact_uri': 'store://models/monitored-model-runner-naive-matanz/SVM#0@c6d1cabe-25b7-469d-8d38-061418fc ...

# %%
async_undefined_mock_server
async_defined_mock_server

# %%
from random import choice
from datetime import datetime

iris_data = iris["data"].tolist()
data_point = choice(iris_data)
print(f"Data point:{data_point}")


print("Before async_sync_function invoke:", datetime.now().strftime("%H:%M:%S.%f"))
async_sync_response = async_undefined_mock_server.test(
    "/",
    body={
        "models": None,
        "inputs": [data_point, data_point],
    },
)
print("After invoke:", datetime.now().strftime("%H:%M:%S.%f"))
# Out:
# Data point:[6.0, 3.4, 4.5, 1.6]
# Before async_sync_function invoke: 12:16:01.098743
# > 2025-10-27 12:16:01,113 [error] Pushing error to error stream: 'coroutine' object has no attribute 'get'
# Traceback (most recent call last):
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/flow.py", line 218, in _do_and_recover
#     return await self._do(event)
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/flow.py", line 664, in _do
#     fn_result = await self._call(element)
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/flow.py", line 654, in _call
#     res = self.do(event)
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/states.py", line 2138, in do
#     errors[model] = event.body.get(model).get("error")
# AttributeError: 'coroutine' object has no attribute 'get'
# > 2025-10-27 12:16:01,120 [error] run error, Traceback (most recent call last):
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/server.py", line 323, in run
#     response = self.graph.run(event, **(extra_args or {}))
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/states.py", line 2666, in run
#     return resp.await_result()
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/sources.py", line 72, in await_result
#     raise copy.copy(result)
# AttributeError: 'coroutine' object has no attribute 'get'
# coroutine 'MyModel.predict' was never awaited
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 10
#       6 print(f"Data point:{data_point}")
#       9 print("Before async_sync_function invoke:", datetime.now().strftime("%H:%M:%S.%f"))
# ---> 10 async_sync_response = async_undefined_mock_server.test(
#      11     "/",
#      12     body={
#      13         "models": None,
#      14         "inputs": [data_point, data_point],
#      15     },
#      16 )
#      17 print("After invoke:", datetime.now().strftime("%H:%M:%S.%f"))
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/server.py:293, in GraphServer.test(self, path, body, method, headers, content_type, silent, get_body, event_id, trigger, offset, time)
#     291 resp = self.run(event, get_body=get_body)
#     292 if hasattr(resp, "status_code") and resp.status_code >= 300 and not silent:
# --> 293     raise RuntimeError(f"failed ({resp.status_code}): {resp.body}")
#     294 return resp
#
# RuntimeError: failed (400): AttributeError: 'coroutine' object has no attribute 'get'

# %%
async_sync_response

# %%
iris_data = iris["data"].tolist()
data_point = choice(iris_data)
print(f"Data point:{data_point}")


print("Before async_sync_function invoke:", datetime.now().strftime("%H:%M:%S.%f"))
async_sync_response = async_defined_mock_server.test(
    "/",
    body={
        "models": None,
        "inputs": [data_point, data_point],
    },
)
print("After invoke:", datetime.now().strftime("%H:%M:%S.%f"))
# Out:
# Data point:[6.5, 3.0, 5.8, 2.2]
# Before async_sync_function invoke: 12:16:35.514336
# > 2025-10-27 12:16:35,527 [error] Pushing error to error stream: 'coroutine' object has no attribute 'get'
# Traceback (most recent call last):
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/flow.py", line 218, in _do_and_recover
#     return await self._do(event)
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/flow.py", line 664, in _do
#     fn_result = await self._call(element)
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/flow.py", line 654, in _call
#     res = self.do(event)
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/states.py", line 2138, in do
#     errors[model] = event.body.get(model).get("error")
# AttributeError: 'coroutine' object has no attribute 'get'
# > 2025-10-27 12:16:35,529 [error] run error, Traceback (most recent call last):
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/server.py", line 323, in run
#     response = self.graph.run(event, **(extra_args or {}))
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/states.py", line 2666, in run
#     return resp.await_result()
#   File "/User/.pythonlibs/mlrun-base/lib/python3.9/site-packages/storey/sources.py", line 72, in await_result
#     raise copy.copy(result)
# AttributeError: 'coroutine' object has no attribute 'get'
# coroutine 'MyModel.predict' was never awaited
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 7
#       3 print(f"Data point:{data_point}")
#       6 print("Before async_sync_function invoke:", datetime.now().strftime("%H:%M:%S.%f"))
# ----> 7 async_sync_response = async_defined_mock_server.test(
#       8     "/",
#       9     body={
#      10         "models": None,
#      11         "inputs": [data_point, data_point],
#      12     },
#      13 )
#      14 print("After invoke:", datetime.now().strftime("%H:%M:%S.%f"))
#
# File ~/.pythonlibs/mlrun-base/lib/python3.9/site-packages/mlrun/serving/server.py:293, in GraphServer.test(self, path, body, method, headers, content_type, silent, get_body, event_id, trigger, offset, time)
#     291 resp = self.run(event, get_body=get_body)
#     292 if hasattr(resp, "status_code") and resp.status_code >= 300 and not silent:
# --> 293     raise RuntimeError(f"failed ({resp.status_code}): {resp.body}")
#     294 return resp
#
# RuntimeError: failed (400): AttributeError: 'coroutine' object has no attribute 'get'

# %%
async_sync_response

# %% [markdown]
# #### 7. Deploying Your Function
#
# Running this cell will deploy your serving function to the cluster. This also deploys the real-time monitoring functions for your project, which are configured to track the serving function's performance and detect model drift.

# %%
async_sync_function.deploy()
bouth_function.deploy()

# %%
iris_data = iris["data"].tolist()
data_point = choice(iris_data)
print(f"Data point:{data_point}")


print("Before async_sync_function invoke:", datetime.now().strftime("%H:%M:%S.%f"))
async_sync_response = async_sync_function.invoke(
    "/",
    body={
        "models": None,
        "inputs": [data_point, data_point],
    },
)
print("After invoke:", datetime.now().strftime("%H:%M:%S.%f"))

# %%
async_sync_response

# %%
iris_data = iris["data"].tolist()
data_point = choice(iris_data)
print(f"Data point:{data_point}")


print("Before bouth_function invoke:", datetime.now().strftime("%H:%M:%S.%f"))
bouth_response = bouth_function.invoke(
    "/",
    body={
        "models": None,
        "inputs": [data_point, data_point],
    },
)
print("After invoke:", datetime.now().strftime("%H:%M:%S.%f"))

# %%
bouth_response

# %%
from random import choice

iris_data = iris["data"].tolist()
data_point = choice(iris_data)
print(f"Data point:{data_point}")
response = function.invoke(
    "/", body={"models": ['my-13-model','my-16-model'], "inputs": [data_point, data_point]}
)

# %%
response

# %% [markdown]
# # TODO
# 2. Check if we get a warning when we try to run async when there is no "async predict"
#
# 3. Check if the async work as expected
#
# 4. Try to add different prompts to the same model using async, and inspect the behavior
